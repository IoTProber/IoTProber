# %%
import pandas as pd

df = pd.read_csv("type_analysis.csv")
df.columns
# Out:
# Index(['class', 'support', 'TP', 'TN', 'FP', 'FN', 'precision', 'recall', 'f1',
#        'accuracy', 'correct', 'misclassified', 'misclf_as_BUILDING_AUTOMATION',
#        'misclf_as_CAMERA', 'misclf_as_GPS', 'misclf_as_HOME_ASSISTANT',
#        'misclf_as_HOME_ROUTER', 'misclf_as_IKE-500', 'misclf_as_IOT',
#        'misclf_as_IOT_GATEWAY', 'misclf_as_IOT_PLATFORM',
#        'misclf_as_MAIL_SERVER', 'misclf_as_MEDIA_SERVER', 'misclf_as_MEDICAL',
#        'misclf_as_MQTT_BROKER', 'misclf_as_NAS', 'misclf_as_NAV',
#        'misclf_as_NAVIGATION', 'misclf_as_NVR', 'misclf_as_POWER_METER',
#        'misclf_as_PRINTER', 'misclf_as_ROUTER', 'misclf_as_SCADA',
#        'misclf_as_SERVER', 'misclf_as_UNKNOWN', 'misclf_as_VPN',
#        'misclf_as_WEB_SERVER'],
#       dtype='object')

# %%
df.head(3)
# Out:
#           class  support      TP   TN   FP      FN  precision  recall      f1  \
# 0  MEDIA_SERVER    12050  7999.0  0.0  0.0  4051.0        1.0  0.6638  0.7979
# 1           VPN     7804   672.0  0.0  0.0  7132.0        1.0  0.0861  0.1586
# 2     MACRO_AVG    19854     NaN  NaN  NaN     NaN        1.0  0.3749  0.4782
#
#    accuracy  ...  misclf_as_NAVIGATION  misclf_as_NVR  misclf_as_POWER_METER  \
# 0    0.6638  ...                   0.0           24.0                    1.0
# 1    0.0861  ...                   1.0           91.0                   12.0
# 2    0.4367  ...                   NaN            NaN                    NaN
#
#    misclf_as_PRINTER  misclf_as_ROUTER  misclf_as_SCADA  misclf_as_SERVER  \
# 0                3.0             135.0              0.0               2.0
# 1                8.0            1609.0             88.0              19.0
# 2                NaN               NaN              NaN               NaN
#
# ...
