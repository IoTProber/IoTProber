# %%
import pandas as pd

devices = ["NAS", "NVR", "POWER_METER", "BUILDING_AUTOMATION", "MEDICAL", "ROUTER", "PRINTER", "SCADA", "CAMERA"]

for dev in devices:
    df = pd.read_csv(f"test_{dev}_1.csv")
    print(f"{dev}: {df.shape}")
# Out:
# NAS: (7557, 46)
# NVR: (3022, 46)
# POWER_METER: (31, 46)
# BUILDING_AUTOMATION: (360, 46)
# MEDICAL: (243, 46)
# ROUTER: (1268, 46)
# PRINTER: (2723, 46)
# SCADA: (565, 46)
# CAMERA: (9930, 46)
