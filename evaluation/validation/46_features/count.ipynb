# %%
import pandas as pd

devices = ["NAS", "NVR", "POWER_METER", "BUILDING_AUTOMATION", "MEDICAL", "ROUTER", "PRINTER", "SCADA", "CAMERA"]

for dev in devices:
    df = pd.read_csv(f"test_{dev}_1.csv")
    print(f"{dev}: {df.shape}")
# Out:
# NAS: (20000, 46)
# NVR: (4474, 46)
# POWER_METER: (996, 46)
# BUILDING_AUTOMATION: (1780, 46)
# MEDICAL: (1493, 46)
# ROUTER: (20000, 46)
# PRINTER: (4332, 46)
# SCADA: (2950, 46)
# CAMERA: (20000, 46)
