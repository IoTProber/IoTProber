# %%
import pandas as pd

devices = ["NAS", "NVR", "POWER_METER", "BUILDING_AUTOMATION", "MEDICAL", "ROUTER", "PRINTER", "SCADA", "CAMERA"]

for dev in devices:
    df = pd.read_csv(f"test_{dev}_1.csv")
    print(f"{dev}: {df.shape}")
# Out:
# NAS: (20000, 45)
# NVR: (4474, 45)
# POWER_METER: (996, 45)
# BUILDING_AUTOMATION: (1780, 45)
# MEDICAL: (1493, 45)
# ROUTER: (20000, 45)
# PRINTER: (4332, 45)
# SCADA: (2950, 45)
# CAMERA: (20000, 46)
